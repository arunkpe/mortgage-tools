# %%
# Loan and LoanAmortizer classes should be defined as in your full implementation.
# This script generates amortization plots for fixed, ARM, HELOC, balloon, and curtailment loans.

import matplotlib.pyplot as plt
import pandas as pd
from datetime import date
from mortgagemodeler import Loan
from mortgagemodeler import LoanAmortizer

# Helper for plotting

def plot_amortization_components(amort_df, title="Loan Amortization", figsize=(12, 5)):
    plt.figure(figsize=figsize)
    plt.plot(amort_df["Month"], amort_df["Principal"], label="Principal")
    plt.plot(amort_df["Month"], amort_df["Interest"], label="Interest")
    if "PMI/MIP" in amort_df.columns:
        plt.plot(amort_df["Month"], amort_df["PMI/MIP"], label="PMI/MIP")
    if "Extra Payment" in amort_df.columns and amort_df["Extra Payment"].max() > 0:
        plt.plot(amort_df["Month"], amort_df["Extra Payment"], label="Extra Payment")
    plt.title(title)
    plt.xlabel("Month")
    plt.ylabel("Monthly Amount ($)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Helper for plotting

def plot_amortization_components(amort_df, title="Loan Amortization", figsize=(12, 5)):
    plt.figure(figsize=figsize)
    plt.plot(amort_df["Month"], amort_df["Principal"], label="Principal")
    plt.plot(amort_df["Month"], amort_df["Interest"], label="Interest")
    if "PMI/MIP" in amort_df.columns:
        plt.plot(amort_df["Month"], amort_df["PMI/MIP"], label="PMI/MIP")
    if "Extra Payment" in amort_df.columns and amort_df["Extra Payment"].max() > 0:
        plt.plot(amort_df["Month"], amort_df["Extra Payment"], label="Extra Payment")
    plt.title(title)
    plt.xlabel("Month")
    plt.ylabel("Monthly Amount ($)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


def plot_arm_payments(loan: Loan, label: str):
    amort = LoanAmortizer(loan)
    df = amort.to_dataframe()
    plt.figure(figsize=(10, 4))
    plt.plot(df["Month"], df["Payment"], label=label)
    plt.title("ARM Monthly Payments Over Time")
    plt.xlabel("Month")
    plt.ylabel("Total Monthly Payment ($)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


def plot_balance_over_time(loan: Loan, label: str, **kwargs):
    amort = LoanAmortizer(loan, **kwargs)
    df = amort.to_dataframe()
    plt.figure(figsize=(10, 4))
    plt.plot(df["Month"], df["Ending Balance"], label=label)
    plt.title(f"Loan Balance Over Time — {label}")
    plt.xlabel("Month")
    plt.ylabel("Ending Balance ($)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Loan definitions (align with actual Loan class, no pmi_rate assumed)

# Simulated forward SOFR values from 2029 onward
custom_rate_schedule = {
    "2029-01-01": 3.75,
    "2029-07-01": 4.25,
    "2030-01-01": 4.75,
    "2030-07-01": 5.25,
    "2031-01-01": 5.50,
    "2031-07-01": 5.75,
    "2032-01-01": 5.50,
    "2032-07-01": 5.25,
    "2033-01-01": 5.00,
}


loan_fixed = Loan.fixed(350000, 360, 0.05, date(2024, 1, 1), pmi=True)
loan_arm_5_6 = Loan.from_arm(350000, 360, '5/6', 'SOFR', 2.25, date(2024, 1, 1), rate=2.25)
loan_arm_7_6 = Loan.from_arm(350000, 360, '7/6', 'SOFR', 2.0, date(2024, 1, 1), rate=2.0)
loan_heloc = Loan(350000, 240, 0.06, date(2024, 1, 1), loan_type='heloc', draw_period_months=120, repayment_term_months=120)
loan_balloon = Loan.fixed(350000, 360, 0.05, date(2024, 1, 1))
loan_curtail = Loan.fixed(350000, 360, 0.05, date(2024, 1, 1))


# ARM Example: Shows reset at 5-year mark
loan_arm = Loan.from_arm(
    principal=500000,
    term=360,
    arm_type="5/6",
    index="SOFR",
    margin=2.5,
    origination_date=date(2020, 1, 1),
    rate=3.0,
    caps=(2, 1, 5),
    floors=(0, 0, 0)
)

# Balloon Example: Ends at 10 years
loan_balloon = Loan.fixed(
    principal=400000,
    term=360,
    rate=4.0,
    origination_date=date(2020, 1, 1)
)

# Curtailment Example: No real recast yet, simulate reduction
loan_curtail = Loan.fixed(
    principal=500000,
    term=360,
    rate=4.0,
    origination_date=date(2020, 1, 1),
    extra_payment_amount=500,
    extra_payment_frequency='monthly'
)

# HELOC Example: Draw for 5 years, repay for 15 years
loan_heloc = Loan(
    principal=300000,
    term_months=240,
    rate=6.0,
    origination_date=date(2020, 1, 1),
    loan_type='heloc',
    draw_period_months=60,
    repayment_term_months=180
)

# %%
# Amortizers
amort_fixed = LoanAmortizer(loan_fixed)
amort_arm_5_6 = LoanAmortizer(loan_arm_5_6,custom_rate_schedule)
amort_arm_7_6 = LoanAmortizer(loan_arm_7_6,custom_rate_schedule)
amort_heloc = LoanAmortizer(loan_heloc)
amort_balloon = LoanAmortizer(loan_balloon, balloon_month=84)  # 7-year balloon
amort_curtail = LoanAmortizer(loan_curtail)  # Curtail logic TBD externally
# Out:
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.

# %%
# Plot
plot_amortization_components(amort_fixed.to_dataframe(), "Fixed Rate Loan with PMI")

# %%
plot_amortization_components(amort_arm_5_6.to_dataframe(), "ARM Loan 5/6 - No Rate Change")

# %%
plot_arm_payments(loan_arm, label="5/6 ARM, Flat Rate")
# Out:
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.

# %%
plot_amortization_components(amort_arm_7_6.to_dataframe(), "ARM Loan 7/6 - No Rate Change")

# %%
plot_balance_over_time(loan_heloc, label="HELOC Draw + Repayment")
# Out:
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.

# %%
plot_balance_over_time(loan_balloon, label="Balloon Loan (10yr)", balloon_month=120)

# %%
plot_balance_over_time(loan_curtail, label="With Monthly Curtailments")

# %%
from datetime import date
from mortgagemodeler.loan import Loan
from mortgagemodeler.amortizer import LoanAmortizer

# Manually override RateReader by injecting a forward curve
forward_curve = {
    "2029-02-01": 4.5,
    "2030-02-01": 5.0,
    "2031-02-01": 5.5,
    "2032-02-01": 6.0,
}

loan_arm = Loan.from_arm(
    principal=500_000,
    term=360,
    arm_type="5/6",
    index="SOFR",
    margin=2.5,
    rate=3.0,
    origination_date=date(2024, 1, 1),
    caps=(2, 1, 5),
    floors=(0, 0, 0),
    forward_curve=forward_curve
)

# Instantiating LoanAmortizer will trigger the debug prints
_ = LoanAmortizer(loan_arm)
# Out:
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.

# %%
amortizer = LoanAmortizer(loan_arm)
# Out:
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.

# %%
amortizer

# %%
plot_arm_payments(loan_arm, label="5/6 ARM, Changing Rate")
# Out:
# ⚠️  RateReader: File not found at /opt/anaconda3/lib/python3.12/site-packages/mortgagemodeler/utils/../data/macroeconforward.txt. Falling back to static index + margin logic.
